# %% [markdown]
# # Data Science Intern @LGMVIP July, 2022
#
# ## Intermediate Level Task - 01
#
# ## Title : Prediction Using DecisionTree Algorithm

# %%
# Importing all the required libraries

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import confusion_matrix

# %%
# Loading the Dataset

df = pd.read_csv('Iris.csv')
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# Finding the shape of the Dataset

df.shape
# Out:
# (150, 6)

# %%
# Getting the Overall Information of the Dataset

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
# Checking for null values in the Dataset

df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
# Counting the Unique Values in the Species Column

df['Species'].value_counts()
# Out:
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        50
# Name: Species, dtype: int64

# %% [markdown]
# ## Graphical Representation of the Features in the Dataset

# %%
# Representing the Frequncy Plot for the Species Column

plt.title('Count-Plot for the 3 different Species of Flowers')
sns.countplot(x=df['Species'])
# Out:
# <AxesSubplot:title={'center':'Count-Plot for the 3 different Species of Flowers'}, xlabel='Species', ylabel='count'>

# %%
sns.displot(x=df['SepalLengthCm'],kde=True).set(title = 'Sepal-Length(cm)')

# %%
sns.displot(x=df['SepalWidthCm'],kde=True).set(title = 'Sepal-Widht(cm)')

# %%
sns.displot(x=df['PetalLengthCm'], kde=True).set(title = 'Petal-Length(cm)')

# %%
sns.displot(x=df['PetalWidthCm'], kde=True).set(title = 'Petal-Widht(cm)')

# %%
plt.subplots(figsize=(15,5))
plt.subplot(1,2,1)
plt.title('Sepal-Length v/s Sepal-Width',fontsize=20)

plt.scatter('SepalLengthCm', 'SepalWidthCm', data = df[df['Species']=='Iris-setosa'], label='Setpsa')
plt.scatter('SepalLengthCm', 'SepalWidthCm', data = df[df['Species']=='Iris-versicolor'], label='Versicolor')
plt.scatter('SepalLengthCm', 'SepalWidthCm', data = df[df['Species']=='Iris-virginica'], label='Virginica')

plt.xlabel('Sepal-Length(cm)')
plt.ylabel('Sepal-Width(cm)')
plt.legend(loc=2)

plt.subplot(1,2,2)
plt.title('Petal-Length v/s Petal-Width',fontsize=20)

plt.scatter('PetalLengthCm', 'PetalWidthCm', data = df[df['Species']=='Iris-setosa'], label='Setpsa')
plt.scatter('PetalLengthCm', 'PetalWidthCm', data = df[df['Species']=='Iris-versicolor'], label='Versicolor')
plt.scatter('PetalLengthCm', 'PetalWidthCm', data = df[df['Species']=='Iris-virginica'], label='Virginica')

plt.xlabel('Petal-Length(cm)')
plt.ylabel('Petal-Width(cm)')
plt.legend(loc=2)

# %% [markdown]
# ## Building of the Classification Model

# %% [markdown]
# ### Encoding the Species Feature using LabelEncoder using sklearn.preprocessing

# %%
le = LabelEncoder()
df['Encoded_Species']= le.fit_transform(df['Species'])

print(df['Encoded_Species'].value_counts())

df
# Out:
# 0    50
# 1    50
# 2    50
# Name: Encoded_Species, dtype: int64
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species  Encoded_Species
# 0       Iris-setosa                0
# 1       Iris-setosa                0
# 2       Iris-setosa                0
# 3       Iris-setosa                0
# 4       Iris-setosa                0
# ..              ...              ...
# 145  Iris-virginica                2
# 146  Iris-virginica                2
# 147  Iris-virginica                2
# 148  Iris-virginica                2
# 149  Iris-virginica                2
#
# [150 rows x 7 columns]

# %% [markdown]
# ### Splitting the Dataset into Train and Test Data

# %%
x = df[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']]
y = df[['Encoded_Species']]

X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.2)

# %%
dTree = DecisionTreeClassifier()

# Training the Decision Tree Model
dTree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# Predicting the values using the X_test data set

predicted_Value = dTree.predict(X_test)
print(predicted_Value)
# Out:
# [1 0 0 2 0 0 1 1 1 2 2 2 0 0 1 1 0 0 0 1 1 2 2 0 1 2 0 2 0 2]

# %%
# Checking the accuracy at the initial stage

dTree.score(X_test, y_test)
# Out:
# 0.9333333333333333

# %% [markdown]
# ### Confusion Matrix for the Real Values v/s The Predicted Values

# %%
plt.title('Confusion Matrix', fontsize=15)
plt.xlabel('Predicted Value')
plt.ylabel('Real Value')

sns.heatmap(confusion_matrix(y_test, predicted_Value), annot=True)
# Out:
# <AxesSubplot:title={'center':'Confusion Matrix'}>

# %% [markdown]
# ### Pictorial View of the Decision Tree

# %%
plt.figure(figsize=(6,8), dpi=150)
plot_tree(dTree, filled=True, feature_names=x.columns, class_names=['Setosa', 'Versicolor', 'Virginica'])
# Out:
# [Text(310.0, 841.2857142857143, 'PetalWidthCm <= 0.75\ngini = 0.666\nsamples = 120\nvalue = [38, 41, 41]\nclass = Versicolor'),
#  Text(232.5, 711.8571428571429, 'gini = 0.0\nsamples = 38\nvalue = [38, 0, 0]\nclass = Setosa'),
#  Text(387.5, 711.8571428571429, 'PetalWidthCm <= 1.75\ngini = 0.5\nsamples = 82\nvalue = [0, 41, 41]\nclass = Versicolor'),
#  Text(232.5, 582.4285714285714, 'PetalLengthCm <= 5.35\ngini = 0.165\nsamples = 44\nvalue = [0, 40, 4]\nclass = Versicolor'),
#  Text(155.0, 453.00000000000006, 'SepalLengthCm <= 4.95\ngini = 0.091\nsamples = 42\nvalue = [0, 40, 2]\nclass = Versicolor'),
#  Text(77.5, 323.57142857142867, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = Virginica'),
#  Text(232.5, 323.57142857142867, 'PetalLengthCm <= 4.95\ngini = 0.048\nsamples = 41\nvalue = [0, 40, 1]\nclass = Versicolor'),
#  Text(155.0, 194.14285714285722, 'gini = 0.0\nsamples = 38\nvalue = [0, 38, 0]\nclass = Versicolor'),
#  Text(310.0, 194.14285714285722, 'SepalWidthCm <= 2.45\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]\nclass = Versicolor'),
#  Text(232.5, 64.71428571428578, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = Virginica'),
#  Text(387.5, 64.71428571428578, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]\nclass = Versicolor'),
#  Text(310.0, 453.00000000000006, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]\nclass = Virginica'),
#  Text(542.5, 582.4285714285714, 'PetalLengthCm <= 4.85\ngini = 0.051\nsamples = 38\nvalue = [0, 1, 37]\nclass = Virginica'),
#  Text(465.0, 453.00000000000006, 'SepalLengthCm <= 5.95\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1]\nclass = Versicolor'),
#  Text(387.5, 323.57142857142867, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = Versicolor'),
#  Text(542.5, 323.57142857142867, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = Virginica'),
#  Text(620.0, 453.00000000000006, 'gini = 0.0\nsamples = 36\nvalue = [0, 0, 36]\nclass = Virginica')]

# %% [markdown]
# ### GridSearchCV :
#
# It is basically a cross-validation technique which is used to search through the best parameter values from the given set of the grid of parameters to get the maximum accuracy.

# %%
# max_depth, min_samples_split and max_leaf_nodes are taken as the parameters for performing the GridSearchCV

params = {'max_depth' : list(range(1,6)), 'min_samples_split' : list(range(1,6)), 'max_leaf_nodes' : list(range(1,6))}

grid_search_cv = GridSearchCV(dTree, params, verbose=1)

grid_search_cv.fit(X_train, y_train)

# %%
# Getting the best-suited parameters for the current dataset to get maximum accuracy

grid_search_cv.best_params_
# Out:
# {'max_depth': 3, 'max_leaf_nodes': 4, 'min_samples_split': 4}

# %%
# Best Score obtained from this GridSearchCV 

grid_search_cv.best_score_
# Out:
# 0.9583333333333334

# %%
# Training the new Decsion Tree Model with the obtained parameters for better performance

dTree = DecisionTreeClassifier(max_depth=2, max_leaf_nodes=3, min_samples_split=2)

dTree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=2, max_leaf_nodes=3)

# %%
# Predicting the values using the X_test data set

predicted_Value = dTree.predict(X_test)
print(predicted_Value)
# Out:
# [1 0 0 2 0 0 1 1 1 2 2 2 0 0 1 1 0 0 0 1 1 2 2 0 1 1 0 2 0 2]

# %%
# Checking the accuracy after altering the parameters

dTree.score(X_test, y_test)
# Out:
# 0.9666666666666667

# %% [markdown]
# The Accuracy has increased to a certain value after altering the parameters

# %%
plt.title('Confusion Matrix', fontsize=15)
plt.xlabel('Predicted Value')
plt.ylabel('Real Value')

sns.heatmap(confusion_matrix(predicted_Value, y_test), annot=True)
# Out:
# <AxesSubplot:title={'center':'Confusion Matrix'}>

# %%
plt.figure(figsize=(4,6), dpi=150)
plot_tree(dTree, filled=True, feature_names=x.columns, class_names=['Setosa', 'Versicolor', 'Virginica']);
